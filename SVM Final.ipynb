# %%
import time
import os

#importing supporting libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import pandas as pd
import seaborn as sns

#importing sklearn libraries for models
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import datasets, linear_model, preprocessing

from sklearn.svm import SVC

# %%
#importing data
train_df = pd.read_csv('sign_mnist_train.csv')
test_df = pd.read_csv('sign_mnist_test.csv')

# %%
#Separating labels and data
y_train = train_df['label']
y_test = test_df['label']

del train_df['label']
del test_df['label']

X_train = train_df.values
X_test = test_df.values

# %%
#Reshaping labels into 2D arrays
y_train = np.array(y_train).reshape((y_train.shape[0],1))
y_test = np.array(y_test).reshape((y_test.shape[0],1))

# %%
#Normalization
X_train = X_train/255.0
X_test = X_test/255.0

# %%
#Checking how the images look like
for i in range(5):
    plt.imshow(X_train[i].reshape((28,28)), cmap=plt.get_cmap('gray'))
    plt.show()

# %%
X_train.data.shape #27455 examples, of 784 pixel vectors 
y_train.data.shape #27455 examples, with one label
# Out:
# (27455, 1)

# %%
def plt_digit(ax, x):
    nrow = 28
    ncol = 28
    xsq = x.reshape((nrow,ncol))
    ax.imshow(xsq,  cmap='Greys_r')
    ax.set_xticks([])
    ax.set_yticks([])
    

# Select random digits
nplt = 8
ntr = X_train.shape[0]
Iperm = np.random.permutation(ntr)

# Plot the images using the subplot command
fig, ax = plt.subplots(1,nplt,figsize=(10,3))
for i in range(nplt):
    ind = Iperm[i]
    plt_digit(ax[i], X_train[ind,:])

# %%
#X_train.shape
#y_train.shape

from sklearn import svm

# Create a classifier: a support vector classifier
svc = svm.SVC(probability=False,  kernel="linear",verbose=10)

# %%
##y_train.shape
#y_train

# %%
svc.fit(X_train,y_train)
# Out:
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LibSVM]*
# optimization finished, #iter = 972
# obj = -1.202841, rho = 0.166918
# nSV = 26, nBSV = 0
# *
# optimization finished, #iter = 398
# obj = -0.578329, rho = -0.252238
# nSV = 23, nBSV = 0
# *.*
# optimization finished, #iter = 1025
# obj = -1.063727, rho = 0.133736
# nSV = 31, nBSV = 0
# .*.*
# optimization finished, #iter = 2564
# obj = -2.965243, rho = 0.032592
# nSV = 48, nBSV = 0
# *
# optimization finished, #iter = 941
# obj = -1.091707, rho = 0.367896
# nSV = 33, nBSV = 0
# *
# optimization finished, #iter = 802
# obj = -0.761884, rho = 0.156641
# nSV = 28, nBSV = 0
# *
# optimization finished, #iter = 714
# obj = -1.272722, rho = 0.769872
# nSV = 26, nBSV = 0
# .*
# ...

# %%
yhat_ts = svc.predict(X_test)
acc = np.mean(yhat_ts == y_test)
print('Accuaracy = {0:f}'.format(acc))
# Out:
# Accuaracy = 0.044126

# %%
svm_score = svc.score(X_test, y_test)
print(svm_score)
# Out:
# 0.7861126603457892

# %%
#THE FOLLOWING PLOTTING WAS JUST A TRIAL REGARDING HOW TO PLOT IMAGES, HOWEVER FIGURED IT WAS USELESS WITH 785 FEATURES. 

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
if not os.path.exists('figures'):
    os.makedirs('figures')

# %%
def format_plot(ax, title):
    ax.xaxis.set_major_formatter(plt.NullFormatter())
    ax.yaxis.set_major_formatter(plt.NullFormatter())
    ax.set_xlabel('feature 1', color='gray')
    ax.set_ylabel('feature 2', color='gray')
    ax.set_title(title, color='gray')

# %%
# plot the data
fig, ax = plt.subplots(figsize=(8, 6))
point_style = dict(cmap='Paired', s=50)
ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, **point_style)
# format plot
format_plot(ax, 'Input Data')
#ax.axis([-1, 4, -2, 7])

#fig.savefig('figures/05.01-classification-1.png')

# %%
import matplotlib.pyplot as plt

# Import datasets, classifiers and performance metrics
from sklearn import datasets, svm, metrics
from sklearn.model_selection import train_test_split

# %%
svc_rbf = svm.SVC(probability=False,  kernel="rbf", verbose=10)
svc_rbf.fit(X_train,y_train)
# Out:
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LibSVM]*
# optimization finished, #iter = 592
# obj = -35.944278, rho = -0.018207
# nSV = 136, nBSV = 26
# *
# optimization finished, #iter = 428
# obj = -20.000655, rho = -0.077966
# nSV = 118, nBSV = 7
# *
# optimization finished, #iter = 546
# obj = -33.510806, rho = 0.016602
# nSV = 140, nBSV = 18
# *
# optimization finished, #iter = 924
# obj = -67.402015, rho = -0.139762
# nSV = 217, nBSV = 69
# *
# optimization finished, #iter = 743
# obj = -35.515887, rho = 0.245504
# nSV = 159, nBSV = 15
# *
# optimization finished, #iter = 400
# obj = -25.696743, rho = 0.133759
# nSV = 126, nBSV = 13
# *
# optimization finished, #iter = 579
# obj = -32.176556, rho = 0.262344
# nSV = 141, nBSV = 21
# *
# ...

# %%
svm_score = svc_rbf.score(X_test, y_test)
print(svm_score)
# Out:
# 0.8418851087562744

# %%
svc_poly = svm.SVC(probability=False,  kernel="poly", verbose=10)
svc_poly.fit(X_train,y_train)
# Out:
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [LibSVM]..*..*
# optimization finished, #iter = 4295
# obj = -0.265068, rho = -0.272503
# nSV = 29, nBSV = 0
# *
# optimization finished, #iter = 485
# obj = -0.118214, rho = -0.366435
# nSV = 23, nBSV = 0
# *
# optimization finished, #iter = 632
# obj = -0.275103, rho = -0.170860
# nSV = 25, nBSV = 0
# .*
# optimization finished, #iter = 1945
# obj = -0.571422, rho = -0.223377
# nSV = 42, nBSV = 0
# *
# optimization finished, #iter = 344
# obj = -0.254120, rho = -0.102898
# nSV = 30, nBSV = 0
# *
# optimization finished, #iter = 440
# obj = -0.151084, rho = -0.304266
# nSV = 28, nBSV = 0
# *
# optimization finished, #iter = 371
# obj = -0.250587, rho = 0.089665
# nSV = 25, nBSV = 0
# .
# ...
# *..*
# ...

# %%
svm_score = svc_poly.score(X_test, y_test)
print(svm_score)
# Out:
# 0.782069157836029

# %%
clf = SVC(kernel='linear', C=.01)
clf.fit(X_train, y_train)
# Out:
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=0.01, kernel='linear')

# %%
score = clf.score(X_test, y_test)
print("Test: "+str(score))
# Out:
# Test: 0.7643614054657

# %%
#score = clf.score(X_train, y_train)
#print("Train: "+str(score))

# %%
from sklearn.model_selection import cross_val_score

parameters = {'C': }
clf = svm.SVC(kernel='linear', random_state=42)
scores = cross_val_score(clf, X_train, y_train, cv=5)
scores
# Out:
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/nikitapola/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 1.00 accuracy with a standard deviation of 0.00

# %%
#The highest test accuracy parameters, with parameters: kernel = rbf, c=.1

clf = SVC(kernel='rbf', C=1)
clf.fit(X_train, y_train)

# %%
print(clf.score(X_test, y_test))
# Out:
# 0.7732849972113776

# %%
print(clf.score(X_train, y_train))
# Out:
# 0.9468220724822437

# %%
y_pred = clf.predict(X_test)
#y_pred = np.argmax(y_pred, axis = 1)
#y_true = np.argmax(y_test, axis = 1)

# %%
conf_matrix = confusion_matrix(y_true, y_pred)

accuracy = sum(conf_matrix[i][i] for i in range(24)) / y_true.shape[0]

plt.figure(figsize=(15,15))
sns.heatmap(conf_matrix, annot=True, fmt=".2f", linewidths=.5, square = True, cmap = 'Reds_r');
plt.ylabel('Actual y')
plt.xlabel('Predicted y')
plt.title('Accuracy Score: {0}'.format(accuracy), size = 15)
